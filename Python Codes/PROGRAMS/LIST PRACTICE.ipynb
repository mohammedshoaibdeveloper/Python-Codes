# %%
alist=["shoaib","khan","Usman"]

# %%
alist
# Out:
# ['shoaib', 'khan', 'Usman']

# %%
city1="karachi"
city2="lahore"
city3="multan"
city4="quetta"
cities=["karachi","lahore","multan","quetta"]

# %%
alist[1]
# Out:
# 'khan'

# %%
cities[3]
# Out:
# 'quetta'

# %%
fruits=[]

# %%
len(fruits)
# Out:
# 0

# %%
len(cities)
# Out:
# 4

# %%
fruits.append("apple")

# %%
fruits
# Out:
# ['apple']

# %%
fruits.append("orange")

# %%
fruits
# Out:
# ['apple', 'orange', 'orange']

# %%
fruits.insert(2,"mango")

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'orange']

# %%
fruits.extend(["apple","cherry","blueberry"])

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'orange', 'apple', 'cherry', 'blueberry']

# %%
fruits.count("orange")
# Out:
# 2

# %%
fruits.index("blueberry")
# Out:
# 6

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
fruits=["apple","cherry","blueberry"]

# %%
fruits2=fruits.copy()

# %%
fruits2
# Out:
# ['apple', 'cherry', 'blueberry']

# %%
fruits3=fruits

# %%
fruits3
# Out:
# ['apple', 'cherry', 'blueberry']

# %%
fruits.append("new fruits")

# %%
fruits3
# Out:
# ['apple', 'cherry', 'blueberry', 'new fruits']

# %%
fruits2
# Out:
# ['apple', 'cherry', 'blueberry']

# %%
del fruits2[1]

# %%
fruits2
# Out:
# ['apple', 'blueberry']

# %%
fruits.remove("blueberry")

# %%
fruits
# Out:
# ['apple', 'cherry', 'new fruits']

# %%
 cities
# Out:
# ['karachi', 'lahore', 'multan', 'quetta']

# %%
poppedcities=cities.pop()
print("the city is popped from list{poppedcities}")
print("the remaining cities are{cities}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-37c0caf9b0b4> in <module>
# ----> 1 poppedcities=cities.pop()
#       2 print("the city is popped from list{poppedcities}")
#       3 print("the remaining cities are{cities}")
#       4
#
# IndexError: pop from empty list

# %%
cities
# Out:
# []

# %%
cities=["karachi","lahore","multan","sukkhur"]

# %%
cities
# Out:
# ['karachi', 'lahore', 'multan', 'sukkhur']

# %%
poppedcities=cities.pop()
print(f"the city is popped from list{poppedcities}")
print(f"the remaining cities are{cities}")
# Out:
# the city is popped from listkarachi
# the remaining cities are[]

# %%
cities=["karachi","lahore","multan","sukkhur"]

# %%
poppedcity=cities.pop(2)

# %%
poppedcity
# Out:
# 'multan'

# %%
cities.sort()

# %%
cities
# Out:
# ['karachi', 'lahore', 'sukkhur']

# %%
cities.sort(reverse=True)

# %%
cities
# Out:
# ['sukkhur', 'lahore', 'karachi']

# %%
cities.reverse()

# %%
cities
# Out:
# ['karachi', 'lahore', 'sukkhur']

# %%
cities[1]
# Out:
# 'lahore'

# %%
cities.index("lahore")
# Out:
# 1

# %%
"karachi" in list of cities
# Out:
#   File "<ipython-input-75-11cb5520fec5>", line 1
#     "karachi" in list of cities
#                        ^
# SyntaxError: invalid syntax

# %%
cities.index("karachi")
# Out:
# 0

# %%
cities[0:3]
# Out:
# ['karachi', 'lahore', 'sukkhur']

# %% [markdown]
# # SLICING

# %%
students=["Ali","Shoaib","usamn","bilal","adil","ibrahim"]
students[4]
# Out:
# 'adil'

# %%
print(students[0])
print(students[-6])
# Out:
# Ali
# Ali

# %%
students[1:3]
# Out:
# ['Shoaib', 'usamn']

# %%
students[-4:-2]
# Out:
# ['usamn', 'bilal']

# %%
students[:]
# Out:
# ['Ali', 'Shoaib', 'usamn', 'bilal', 'adil', 'ibrahim']

# %%
students[3:]
# Out:
# ['bilal', 'adil', 'ibrahim']

# %%
students[:3]
# Out:
# ['Ali', 'Shoaib', 'usamn']

# %%
students[2:-1]
# Out:
# ['usamn', 'bilal', 'adil']

# %%
students[2:-6]
# Out:
# []

# %%
nums=[1,2,3,4,55,6,7,8,3,5,6,7,8,5,4,4,5,67,7,5,3,5,7,8,4,4]
nums[0:10:1]
# Out:
# [1, 2, 3, 4, 55, 6, 7, 8, 3, 5]

# %%
nums[0:10:2]
# Out:
# [1, 3, 55, 7, 3]

# %%
nums[::5]
# Out:
# [1, 6, 6, 4, 3, 4]

# %% [markdown]
# # #Tupples

# %%
 tupple=("Mohammed",100,"shoaib")

# %%
len(tupple)
# Out:
# 3

# %%
 a=67,45,678,3434,556

# %%
a
# Out:
# (67, 45, 678, 3434, 556)

# %%
a.index(45
       )
# Out:
# 1

# %%
a.index(45
       )
# Out:
# 1
